# %%
import os
import json
import glob

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
print("numpy/scipy imports:")
import numpy as np
from scipy import signal as sg
import scipy.ndimage as ndimage
from scipy.ndimage.filters import maximum_filter
# Out:
# numpy/scipy imports:

# %%
default_base = './data'
# flist = glob.glob(os.path.join(default_base, '*_leftImg8bit.png'))
flist = glob.glob(os.path.join(default_base, 'munster_000023_000019_leftImg8bit.png'))

# kernal_leftImg8bit

# %%
# plt.imshow(res,cmap='gray')

# %%
# filter_kernel = np.ones((5,5),np.float32)/25
# res = ndimage.filters.convolve(image, filter_kernel)
# plt.imshow(res,cmap='gray')

# %%
image_path = flist[0]
image = np.array(Image.open(image_path).convert("L"))
plt.figure().clf()
plt.imshow(image, cmap='gray')
plt.show()

# %%
filter_kernel = [[-2/9, -2/9,- 2/9, -2/9,- 2/9],
                 [-2/9, -2/9,-2/9, -2/9,- 2/9],
                 [-2/9, -2/9, 48/9, -2/9,- 2/9], 
                 [-2/9, -2/9,- 2/9, -2/9,- 2/9],
                 [-2/9, -2/9,-2/9, -2/9,- 2/9]]

res = sg.convolve2d(image, filter_kernel)
plt.imshow(res,cmap='gray')

# %%
filter_kernel = [[-1/9, -1/9,- 1/9],
                 [-1/9, 8/9,-1/9],
                 [-1/9, -1/9, -1/9]]

plt.imshow(filter_kernel,cmap='gray')

res = ndimage.filters.convolve(image, filter_kernel)
plt.imshow(res,cmap='gray')

# %%
image_path = flist[0]
image = np.array(Image.open(image_path).convert("L"))
image2 = image[206:239, 417:452]
image2.shape
# Out:
# (33, 35)

# %%
plt.imshow(image2, cmap='gray')
plt.show()

# %%
filter_kernel = image2
res = ndimage.filters.convolve(image, filter_kernel)
plt.imshow(res,cmap='gray')

# %%
filter_kernel
sum(filter_kernel.ravel())
# Out:
# 81670
